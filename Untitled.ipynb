# %%
import pandas as pd
import numpy as np

# %%
airport_data = pd.read_csv('./airfare_all_pairs.csv')
# Out:
# /var/folders/b2/tb76467j57b1skfz14105p_80000gn/T/ipykernel_95295/3743751362.py:1: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   airport_data = pd.read_csv('./airfare_all_pairs.csv')

# %%
airport_data_subset = airport_data.loc[airport_data['Year']==2024]
del airport_data

# %%
airport_data_subset.columns
# Out:
# Index(['tbl', 'Year', 'quarter', 'citymarketid_1', 'citymarketid_2', 'city1',
#        'city2', 'airportid_1', 'airportid_2', 'airport_1', 'airport_2',
#        'nsmiles', 'passengers', 'fare', 'carrier_lg', 'large_ms', 'fare_lg',
#        'carrier_low', 'lf_ms', 'fare_low', 'Geocoded_City1', 'Geocoded_City2',
#        'tbl1apk'],
#       dtype='object')

# %%
airport_data_subset.loc[airport_data_subset['airport_1']=='IAH'][['airport_1','airport_2','city2','nsmiles','fare','carrier_lg']]

# %%
busiest_routes = pd.read_csv('./busiest_routes.csv')

# %%
busiest_routes_subset = busiest_routes.loc[busiest_routes['Year']==2024]
del busiest_routes

# %%
busiest_routes_subset.sort_values(by=['passengers'], ascending=False)[0:50]
# Out:
#         Year  quarter  citymarketid_1  citymarketid_2  \
# 112814  2024        1           32467           31703
# 112847  2024        1           32575           32457
# 112677  2024        1           31703           31454
# 112845  2024        1           32575           31703
# 112687  2024        1           31703           34027
# 112441  2024        1           30977           31703
# 112196  2024        1           30397           31703
# 112679  2024        1           31703           32457
# 112759  2024        1           32211           32575
# 112839  2024        1           32575           30559
# 112810  2024        1           32467           30852
# 112757  2024        1           32211           32457
# 112618  2024        1           31454           30852
# 112681  2024        1           31703           33195
# 112375  2024        1           30721           31454
# 112082  2024        1           30194           32575
# ...
